# %%
from jina import Client

# %%
from docarray import Document, DocumentArray
from multiprocessing import Process, Queue
import time
import uuid

# %%
client = Client(port=51005)

# %%
client.dry_run()
# Out:
# True

# %%
def get_doc():
    doc = Document(uri='https://raw.githubusercontent.com/fastai/fastai/master/nbs/images/puppy.jpg')
    return doc.load_uri_to_blob()

# %%
client.index(inputs=[get_doc() for _ in range(10)])
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────── Documents Summary ──────────────────────╮
# │                                                               │
# │   Length                 10                                   │
# │   Homogenous Documents   True                                 │
# │   Common Attributes      ('id', 'blob', 'mime_type', 'uri')   │
# │   Multimodal dataclass   False                                │
# │                                                               │
# ╰───────────────────────────────────────────────────────────────╯
# ╭───────────────────── Attributes Summary ──────────────────────╮
# │                                                               │
# │   Attribute   Data type    #Unique values   Has empty value   │
# │  ───────────────────────────────────────────────────────────  │
# │   blob        ('bytes',)   1                False             │
# │   id          ('str',)     10               False             │
# │   mime_type   ('str',)     1                False             │
# │   uri         ('str',)     1                False             │
# │                                                               │
# ╰───────────────────────────────────────────────────────────────╯

# %%
def post_request(queue):
    """Full dalle flow run"""
    id_ = str(uuid.uuid1())
    init_time= time.time()
    
    print(f'hello {id_} \n')
    
    client = Client(port=51005)    
    client.index(inputs=[get_doc() for _ in range(10)])    
    
    print(f'byebye {id_} \n time spent: {time.time()-init_time} \n queue size: {q.qsize()}')
    print(time.time()-init_time)
    q.put(id_)

# %%
N = 10

q = Queue()

list_thread = [Process(target=post_request, args=(q,), daemon=True) for _ in range(N)]

# + tags=[]
# %%time
for t in list_thread:
    t.start()
for t in list_thread:
    t.join()
# -

print(f'{N - q.qsize() } failed')
# Out:
# hello f250a006-1274-11ed-b5b5-2190e38b9d72
#
# hello f25108e8-1274-11ed-b5b5-2190e38b9d72
#
# hello f251a460-1274-11ed-b5b5-2190e38b9d72
#
# hello f252252a-1274-11ed-b5b5-2190e38b9d72
#
# hello f2529a8c-1274-11ed-b5b5-2190e38b9d72
#
# hello f25330fa-1274-11ed-b5b5-2190e38b9d72
#
# hello f253c09c-1274-11ed-b5b5-2190e38b9d72
#
# hello f2545fb6-1274-11ed-b5b5-2190e38b9d72
#
# hello f254e90e-1274-11ed-b5b5-2190e38b9d72
#
# hello f2556e2e-1274-11ed-b5b5-2190e38b9d72
# Process Process-171:
# Process Process-172:
# Process Process-169:
# Process Process-173:
# Process Process-168:
# Process Process-164:
# Process Process-166:
# Process Process-170:
# Process Process-167:
# Process Process-165:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_306320/1977653078.py", line 9, in post_request
#     client.index(inputs=[get_doc() for _ in range(10)])
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_306320/1977653078.py", line 9, in post_request
#     client.index(inputs=[get_doc() for _ in range(10)])
#   File "/tmp/ipykernel_306320/1977653078.py", line 9, in <listcomp>
#     client.index(inputs=[get_doc() for _ in range(10)])
# Traceback (most recent call last):
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/tmp/ipykernel_306320/1977653078.py", line 9, in <listcomp>
#     client.index(inputs=[get_doc() for _ in range(10)])
#   File "/tmp/ipykernel_306320/2821389165.py", line 3, in get_doc
#     return doc.load_uri_to_blob()
#   File "/tmp/ipykernel_306320/1977653078.py", line 9, in post_request
#     client.index(inputs=[get_doc() for _ in range(10)])
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_306320/1977653078.py", line 9, in post_request
#     client.index(inputs=[get_doc() for _ in range(10)])
#   File "/tmp/ipykernel_306320/1977653078.py", line 9, in post_request
#     client.index(inputs=[get_doc() for _ in range(10)])
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/tmp/ipykernel_306320/1977653078.py", line 9, in <listcomp>
#     client.index(inputs=[get_doc() for _ in range(10)])
#   File "/home/sami/Documents/workspace/Jina/docarray/docarray/document/mixins/blob.py", line 18, in load_uri_to_blob
#     self.blob = _uri_to_blob(self.uri)
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_306320/1977653078.py", line 9, in post_request
#     client.index(inputs=[get_doc() for _ in range(10)])
#   File "/tmp/ipykernel_306320/1977653078.py", line 9, in <listcomp>
#     client.index(inputs=[get_doc() for _ in range(10)])
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_306320/1977653078.py", line 9, in <listcomp>
#     client.index(inputs=[get_doc() for _ in range(10)])
#   File "/tmp/ipykernel_306320/1977653078.py", line 9, in post_request
#     client.index(inputs=[get_doc() for _ in range(10)])
#   File "/tmp/ipykernel_306320/2821389165.py", line 3, in get_doc
#     return doc.load_uri_to_blob()
#   File "/home/sami/Documents/workspace/Jina/docarray/docarray/document/mixins/helper.py", line 16, in _uri_to_blob
#     with urllib.request.urlopen(req) as fp:
#   File "/tmp/ipykernel_306320/2821389165.py", line 3, in get_doc
#     return doc.load_uri_to_blob()
#   File "/tmp/ipykernel_306320/1977653078.py", line 9, in post_request
#     client.index(inputs=[get_doc() for _ in range(10)])
#   File "/tmp/ipykernel_306320/1977653078.py", line 9, in post_request
#     client.index(inputs=[get_doc() for _ in range(10)])
#   File "/tmp/ipykernel_306320/2821389165.py", line 3, in get_doc
#     return doc.load_uri_to_blob()
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/urllib/request.py", line 214, in urlopen
#     return opener.open(url, data, timeout)
#   File "/tmp/ipykernel_306320/1977653078.py", line 9, in <listcomp>
#     client.index(inputs=[get_doc() for _ in range(10)])
#   File "/home/sami/Documents/workspace/Jina/docarray/docarray/document/mixins/blob.py", line 18, in load_uri_to_blob
#     self.blob = _uri_to_blob(self.uri)
#   File "/tmp/ipykernel_306320/1977653078.py", line 9, in <listcomp>
#     client.index(inputs=[get_doc() for _ in range(10)])
#   File "/home/sami/Documents/workspace/Jina/docarray/docarray/document/mixins/blob.py", line 18, in load_uri_to_blob
#     self.blob = _uri_to_blob(self.uri)
#   File "/tmp/ipykernel_306320/1977653078.py", line 9, in <listcomp>
#     client.index(inputs=[get_doc() for _ in range(10)])
#   File "/tmp/ipykernel_306320/1977653078.py", line 9, in <listcomp>
#     client.index(inputs=[get_doc() for _ in range(10)])
#   File "/home/sami/Documents/workspace/Jina/docarray/docarray/document/mixins/blob.py", line 18, in load_uri_to_blob
#     self.blob = _uri_to_blob(self.uri)
#   File "/tmp/ipykernel_306320/2821389165.py", line 3, in get_doc
#     return doc.load_uri_to_blob()
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/urllib/request.py", line 517, in open
#     response = self._open(req, data)
#   File "/home/sami/Documents/workspace/Jina/docarray/docarray/document/mixins/helper.py", line 16, in _uri_to_blob
#     with urllib.request.urlopen(req) as fp:
#   File "/tmp/ipykernel_306320/2821389165.py", line 3, in get_doc
#     return doc.load_uri_to_blob()
#   File "/tmp/ipykernel_306320/2821389165.py", line 3, in get_doc
#     return doc.load_uri_to_blob()
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/urllib/request.py", line 214, in urlopen
#     return opener.open(url, data, timeout)
#   File "/tmp/ipykernel_306320/2821389165.py", line 3, in get_doc
#     return doc.load_uri_to_blob()
#   File "/home/sami/Documents/workspace/Jina/docarray/docarray/document/mixins/blob.py", line 18, in load_uri_to_blob
#     self.blob = _uri_to_blob(self.uri)
#   File "/home/sami/Documents/workspace/Jina/docarray/docarray/document/mixins/helper.py", line 16, in _uri_to_blob
#     with urllib.request.urlopen(req) as fp:
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/urllib/request.py", line 534, in _open
#     result = self._call_chain(self.handle_open, protocol, protocol +
#   File "/tmp/ipykernel_306320/2821389165.py", line 3, in get_doc
#     return doc.load_uri_to_blob()
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/urllib/request.py", line 517, in open
#     response = self._open(req, data)
#   File "/home/sami/Documents/workspace/Jina/docarray/docarray/document/mixins/blob.py", line 18, in load_uri_to_blob
#     self.blob = _uri_to_blob(self.uri)
#   File "/home/sami/Documents/workspace/Jina/docarray/docarray/document/mixins/blob.py", line 18, in load_uri_to_blob
#     self.blob = _uri_to_blob(self.uri)
#   File "/home/sami/Documents/workspace/Jina/docarray/docarray/document/mixins/blob.py", line 18, in load_uri_to_blob
#     self.blob = _uri_to_blob(self.uri)
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/urllib/request.py", line 214, in urlopen
#     return opener.open(url, data, timeout)
#   File "/home/sami/Documents/workspace/Jina/docarray/docarray/document/mixins/blob.py", line 18, in load_uri_to_blob
#     self.blob = _uri_to_blob(self.uri)
#   File "/home/sami/Documents/workspace/Jina/docarray/docarray/document/mixins/helper.py", line 16, in _uri_to_blob
#     with urllib.request.urlopen(req) as fp:
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/urllib/request.py", line 534, in _open
#     result = self._call_chain(self.handle_open, protocol, protocol +
#   File "/home/sami/Documents/workspace/Jina/docarray/docarray/document/mixins/helper.py", line 17, in _uri_to_blob
#     return fp.read()
#   File "/home/sami/Documents/workspace/Jina/docarray/docarray/document/mixins/helper.py", line 17, in _uri_to_blob
#     return fp.read()
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/urllib/request.py", line 517, in open
#     response = self._open(req, data)
#   File "/home/sami/Documents/workspace/Jina/docarray/docarray/document/mixins/helper.py", line 16, in _uri_to_blob
#     with urllib.request.urlopen(req) as fp:
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/urllib/request.py", line 214, in urlopen
#     return opener.open(url, data, timeout)
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/http/client.py", line 476, in read
#     s = self._safe_read(self.length)
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/urllib/request.py", line 494, in _call_chain
#     result = func(*args)
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/http/client.py", line 476, in read
#     s = self._safe_read(self.length)
#   File "/home/sami/Documents/workspace/Jina/docarray/docarray/document/mixins/helper.py", line 17, in _uri_to_blob
#     return fp.read()
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/urllib/request.py", line 534, in _open
#     result = self._call_chain(self.handle_open, protocol, protocol +
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/http/client.py", line 626, in _safe_read
#     chunk = self.fp.read(min(amt, MAXAMOUNT))
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/urllib/request.py", line 517, in open
#     response = self._open(req, data)
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/urllib/request.py", line 1389, in https_open
#     return self.do_open(http.client.HTTPSConnection, req,
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/urllib/request.py", line 214, in urlopen
#     return opener.open(url, data, timeout)
#   File "/tmp/ipykernel_306320/1977653078.py", line 9, in post_request
#     client.index(inputs=[get_doc() for _ in range(10)])
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/urllib/request.py", line 534, in _open
#     result = self._call_chain(self.handle_open, protocol, protocol +
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/urllib/request.py", line 1350, in do_open
#     r = h.getresponse()
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/http/client.py", line 476, in read
#     s = self._safe_read(self.length)
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/urllib/request.py", line 494, in _call_chain
#     result = func(*args)
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/http/client.py", line 626, in _safe_read
#     chunk = self.fp.read(min(amt, MAXAMOUNT))
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/http/client.py", line 1377, in getresponse
#     response.begin()
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/http/client.py", line 626, in _safe_read
#     chunk = self.fp.read(min(amt, MAXAMOUNT))
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/urllib/request.py", line 517, in open
#     response = self._open(req, data)
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/urllib/request.py", line 494, in _call_chain
#     result = func(*args)
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/urllib/request.py", line 1389, in https_open
#     return self.do_open(http.client.HTTPSConnection, req,
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/http/client.py", line 320, in begin
#     version, status, reason = self._read_status()
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/urllib/request.py", line 1389, in https_open
#     return self.do_open(http.client.HTTPSConnection, req,
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/urllib/request.py", line 1350, in do_open
#     r = h.getresponse()
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/http/client.py", line 281, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/socket.py", line 704, in readinto
#     return self._sock.recv_into(b)
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/urllib/request.py", line 1350, in do_open
#     r = h.getresponse()
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/http/client.py", line 1377, in getresponse
#     response.begin()
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/socket.py", line 704, in readinto
#     return self._sock.recv_into(b)
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/urllib/request.py", line 534, in _open
#     result = self._call_chain(self.handle_open, protocol, protocol +
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/socket.py", line 704, in readinto
#     return self._sock.recv_into(b)
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/http/client.py", line 1377, in getresponse
#     response.begin()
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/urllib/request.py", line 494, in _call_chain
#     result = func(*args)
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/http/client.py", line 320, in begin
#     version, status, reason = self._read_status()
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/http/client.py", line 320, in begin
#     version, status, reason = self._read_status()
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/http/client.py", line 281, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/urllib/request.py", line 1389, in https_open
#     return self.do_open(http.client.HTTPSConnection, req,
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/http/client.py", line 281, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
# KeyboardInterrupt
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/socket.py", line 704, in readinto
#     return self._sock.recv_into(b)
# KeyboardInterrupt
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/urllib/request.py", line 1350, in do_open
#     r = h.getresponse()
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/http/client.py", line 1377, in getresponse
#     response.begin()
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/http/client.py", line 320, in begin
#     version, status, reason = self._read_status()
# KeyboardInterrupt
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/http/client.py", line 281, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/socket.py", line 704, in readinto
#     return self._sock.recv_into(b)
# KeyboardInterrupt
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/socket.py", line 704, in readinto
#     return self._sock.recv_into(b)
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/socket.py", line 704, in readinto
#     return self._sock.recv_into(b)
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/urllib/request.py", line 494, in _call_chain
#     result = func(*args)
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
#   File "/tmp/ipykernel_306320/1977653078.py", line 9, in <listcomp>
#     client.index(inputs=[get_doc() for _ in range(10)])
# KeyboardInterrupt
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
#   File "/tmp/ipykernel_306320/2821389165.py", line 3, in get_doc
#     return doc.load_uri_to_blob()
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/urllib/request.py", line 1389, in https_open
#     return self.do_open(http.client.HTTPSConnection, req,
#   File "/home/sami/Documents/workspace/Jina/docarray/docarray/document/mixins/blob.py", line 18, in load_uri_to_blob
#     self.blob = _uri_to_blob(self.uri)
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/urllib/request.py", line 1346, in do_open
#     h.request(req.get_method(), req.selector, req.data, headers,
#   File "/home/sami/Documents/workspace/Jina/docarray/docarray/document/mixins/helper.py", line 16, in _uri_to_blob
#     with urllib.request.urlopen(req) as fp:
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/urllib/request.py", line 214, in urlopen
#     return opener.open(url, data, timeout)
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/http/client.py", line 1285, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/urllib/request.py", line 517, in open
#     response = self._open(req, data)
# KeyboardInterrupt
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/http/client.py", line 1331, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/http/client.py", line 1280, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/http/client.py", line 1040, in _send_output
#     self.send(msg)
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/http/client.py", line 980, in send
#     self.connect()
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/urllib/request.py", line 534, in _open
#     result = self._call_chain(self.handle_open, protocol, protocol +
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/http/client.py", line 1454, in connect
#     self.sock = self._context.wrap_socket(self.sock,
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/urllib/request.py", line 494, in _call_chain
#     result = func(*args)
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/ssl.py", line 500, in wrap_socket
#     return self.sslsocket_class._create(
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/urllib/request.py", line 1389, in https_open
#     return self.do_open(http.client.HTTPSConnection, req,
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/ssl.py", line 1040, in _create
#     self.do_handshake()
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/ssl.py", line 1309, in do_handshake
#     self._sslobj.do_handshake()
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/urllib/request.py", line 1350, in do_open
#     r = h.getresponse()
# KeyboardInterrupt
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/http/client.py", line 1377, in getresponse
#     response.begin()
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/http/client.py", line 320, in begin
#     version, status, reason = self._read_status()
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/http/client.py", line 281, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/socket.py", line 704, in readinto
#     return self._sock.recv_into(b)
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/sami/Documents/workspace/Jina/docarray/docarray/document/mixins/helper.py", line 17, in _uri_to_blob
#     return fp.read()
# KeyboardInterrupt
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/http/client.py", line 476, in read
#     s = self._safe_read(self.length)
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/http/client.py", line 626, in _safe_read
#     chunk = self.fp.read(min(amt, MAXAMOUNT))
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/socket.py", line 704, in readinto
#     return self._sock.recv_into(b)
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "/home/sami/.pyenv/versions/3.9.10/lib/python3.9/ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [70], in <module>
#      10     t.start()
#      11 for t in list_thread:
# ---> 12     t.join()
#      13 # -
#      15 print(f'{N - q.qsize() } failed')
#
# File ~/.pyenv/versions/3.9.10/lib/python3.9/multiprocessing/process.py:149, in BaseProcess.join(self, timeout)
#     147 assert self._parent_pid == os.getpid(), 'can only join a child process'
#     148 assert self._popen is not None, 'can only join a started process'
# --> 149 res = self._popen.wait(timeout)
#     150 if res is not None:
#     151     _children.discard(self)
#
# File ~/.pyenv/versions/3.9.10/lib/python3.9/multiprocessing/popen_fork.py:43, in Popen.wait(self, timeout)
#      41             return None
#      42     # This shouldn't block if wait() returned successfully.
# ---> 43     return self.poll(os.WNOHANG if timeout == 0.0 else 0)
#      44 return self.returncode
#
# File ~/.pyenv/versions/3.9.10/lib/python3.9/multiprocessing/popen_fork.py:27, in Popen.poll(self, flag)
#      25 if self.returncode is None:
#      26     try:
# ---> 27         pid, sts = os.waitpid(self.pid, flag)
#      28     except OSError:
#      29         # Child process not yet created. See #1731717
#      30         # e.errno == errno.ECHILD == 10
#      31         return None
#
# KeyboardInterrupt:

# %%
import numpy as np

# %%
matrix = np.random.rand(20_000, 4_000)

# %%
matrix.nbytes/ 1024**2
# Out:
# 610.3515625
